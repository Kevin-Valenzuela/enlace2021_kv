# %% [markdown]
# # Variables of households and population of Mexican States in 2020
#
# This Notebook uses the households and population dataframe of Mexican States (admin1) derived from the 2020 Mexican Census: [INEGI](https://inegi.org.mx/programas/ccpv/2020/#Datos_abiertos).
#
# Due its size the dataset "conjunto_de_datos_iter_00CSV20.csv" must be manually downloaded form the section 'Principales resultados por localidad (ITER)' and subsection 'Estados Unidos Mexicanos' where it will be found. After downloading  there will be a zip file in which the data will be located on one of the folders called. This dataset it must be relocated to the data folder.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from string import ascii_letters
import numpy as np

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Read Variables of households and population of Mexico in 2020

# %%
df = pd.read_csv('../data/conjunto_de_datos_iter_00CSV20.csv')
# Out:
# C:\Users\TheAl\miniconda3\envs\enlace2021_av\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# By using this query only the totals of each variable for each municipality is used well the rest of the dataframe is ignored.

# %%
df.query("NOM_LOC == 'Total de la Entidad'", inplace = True)
df
# Out:
#         ENTIDAD                          NOM_ENT  MUN  \
# 3             1                   Aguascalientes    0
# 2061          2                  Baja California    0
# 7627          3              Baja California Sur    0
# 10188         4                         Campeche    0
# 12988         5             Coahuila de Zaragoza    0
# 17137         6                           Colima    0
# 18396         7                          Chiapas    0
# 39883         8                        Chihuahua    0
# 52272         9                 Ciudad de México    0
# 52938        10                          Durango    0
# 58944        11                       Guanajuato    0
# 67889        12                         Guerrero    0
# 74890        13                          Hidalgo    0
# 79806        14                          Jalisco    0
# 90521        15                           México    0
# 95657        16              Michoacán de Ocampo    0
# 104613       17                          Morelos    0
# 106291       18                          Nayarit    0
# 109204       19                       Nuevo León    0
# 114178       20                           Oaxaca    0
# 126034       21                           Puebla    0
# 133093       22                        Querétaro    0
# 135342       23                     Quintana Roo    0
# 137585       24                  San Luis Potosí    0
# 144314       25                          Sinaloa    0
# 149866       26                           Sonora    0
# 157366       27                          Tabasco    0
# 159883       28                       Tamaulipas    0
# 166578       29                         Tlaxcala    0
# 167901       30  Veracruz de Ignacio de la Llave    0
# 188302       31                          Yucatán    0
# 190993       32                        Zacatecas    0
#
#                                                   NOM_MUN  LOC  \
# 3                      Total de la entidad Aguascalientes    0
# 2061                  Total de la entidad Baja California    0
# 7627              Total de la entidad Baja California Sur    0
# 10188                        Total de la entidad Campeche    0
# 12988            Total de la entidad Coahuila de Zaragoza    0
# 17137                          Total de la entidad Colima    0
# 18396                         Total de la entidad Chiapas    0
# 39883                       Total de la entidad Chihuahua    0
# 52272                Total de la entidad Ciudad de México    0
# 52938                         Total de la entidad Durango    0
# 58944                      Total de la entidad Guanajuato    0
# 67889                        Total de la entidad Guerrero    0
# 74890                         Total de la entidad Hidalgo    0
# 79806                         Total de la entidad Jalisco    0
# 90521                          Total de la entidad México    0
# 95657             Total de la entidad Michoacán de Ocampo    0
# 104613                        Total de la entidad Morelos    0
# 106291                        Total de la entidad Nayarit    0
# 109204                     Total de la entidad Nuevo León    0
# 114178                         Total de la entidad Oaxaca    0
# 126034                         Total de la entidad Puebla    0
# 133093                      Total de la entidad Querétaro    0
# 135342                   Total de la entidad Quintana Roo    0
# 137585                Total de la entidad San Luis Potosí    0
# 144314                        Total de la entidad Sinaloa    0
# 149866                         Total de la entidad Sonora    0
# 157366                        Total de la entidad Tabasco    0
# 159883                     Total de la entidad Tamaulipas    0
# 166578                       Total de la entidad Tlaxcala    0
# 167901  Total de la entidad Veracruz de Ignacio de la ...    0
# 188302                        Total de la entidad Yucatán    0
# 190993                      Total de la entidad Zacatecas    0
#
#                     NOM_LOC LONGITUD LATITUD ALTITUD    POBTOT  ...  VPH_CEL  \
# 3       Total de la Entidad      NaN     NaN     NaN   1425607  ...   359895
# 2061    Total de la Entidad      NaN     NaN     NaN   3769020  ...  1080169
# 7627    Total de la Entidad      NaN     NaN     NaN    798447  ...   226517
# 10188   Total de la Entidad      NaN     NaN     NaN    928363  ...   218322
# 12988   Total de la Entidad      NaN     NaN     NaN   3146771  ...   824291
# 17137   Total de la Entidad      NaN     NaN     NaN    731391  ...   206736
# 18396   Total de la Entidad      NaN     NaN     NaN   5543828  ...   944695
# 39883   Total de la Entidad      NaN     NaN     NaN   3741869  ...  1051045
# 52272   Total de la Entidad      NaN     NaN     NaN   9209944  ...  2536523
# 52938   Total de la Entidad      NaN     NaN     NaN   1832650  ...   434450
# 58944   Total de la Entidad      NaN     NaN     NaN   6166934  ...  1381668
# 67889   Total de la Entidad      NaN     NaN     NaN   3540685  ...   715753
# 74890   Total de la Entidad      NaN     NaN     NaN   3082841  ...   727888
# 79806   Total de la Entidad      NaN     NaN     NaN   8348151  ...  2134429
# 90521   Total de la Entidad      NaN     NaN     NaN  16992418  ...  4049493
# 95657   Total de la Entidad      NaN     NaN     NaN   4748846  ...  1123169
# 104613  Total de la Entidad      NaN     NaN     NaN   1971520  ...   499787
# 106291  Total de la Entidad      NaN     NaN     NaN   1235456  ...   318700
# 109204  Total de la Entidad      NaN     NaN     NaN   5784442  ...  1537687
# 114178  Total de la Entidad      NaN     NaN     NaN   4132148  ...   812319
# 126034  Total de la Entidad      NaN     NaN     NaN   6583278  ...  1444126
# 133093  Total de la Entidad      NaN     NaN     NaN   2368467  ...   606978
# 135342  Total de la Entidad      NaN     NaN     NaN   1857985  ...   526202
# 137585  Total de la Entidad      NaN     NaN     NaN   2822255  ...   653195
# 144314  Total de la Entidad      NaN     NaN     NaN   3026943  ...   787350
# 149866  Total de la Entidad      NaN     NaN     NaN   2944840  ...   811378
# 157366  Total de la Entidad      NaN     NaN     NaN   2402598  ...   563390
# 159883  Total de la Entidad      NaN     NaN     NaN   3527735  ...   985027
# 166578  Total de la Entidad      NaN     NaN     NaN   1342977  ...   289686
# 167901  Total de la Entidad      NaN     NaN     NaN   8062579  ...  1971776
# 188302  Total de la Entidad      NaN     NaN     NaN   2320898  ...   580440
# 190993  Total de la Entidad      NaN     NaN     NaN   1622138  ...   372814
#
#        VPH_INTER VPH_STVP VPH_SPMVPI VPH_CVJ VPH_SINRTV VPH_SINLTC  \
# 3         236003   174089      98724   70126       6021      15323
# 2061      800189   618175     384011  216865      41223      38772
# 7627      148723   136538      67961   36197      14508       8675
# 10188     114020   151613      38508   17976      23627      36397
# 12988     519599   443659     195883  124077      17020      46420
# 17137     132395   114164      43881   22695       9173      12085
# 18396     292189   433400      61298   32460     214333     379915
# 39883     650546   481871     282049  179964      42113      64419
# 52272    2084156  1290811     957162  568827      46172      77272
# 52938     215108   222785      73099   54664      22071      41801
# 58944     764350   681879     240833  167748      46126     134421
# 67889     298180   343146      56999   28577     125684     172608
# 74890     332320   378326      95701   64475      51691     102005
# 79806    1437473  1199700     573528  375678      56399      96948
# 90521    2561525  1559564     822048  572663     133777     329132
# 95657     561753   684146     149704  101530      57579     111766
# 104613    307830   222853      90825   48209      24696      34950
# 106291    169289   178574      60325   35983      20501      28481
# 109204   1150914   806584     490746  306104      36729      57505
# 114178    329811   321144      60715   29789     181771     263541
# 126034    691363   539920     213909  129993     102541     207818
# 133093    430045   382086     183742  106431      22702      44358
# 135342    319194   267556     131827   55902      43642      36378
# 137585    344443   347311     128861   83293      43489      90622
# 144314    441062   457908     162367   92477      35425      50477
# 149866    530511   501521     210780  126299      32807      48777
# 157366    228487   276817      66338   31004      54983      96508
# 159883    580241   434549     197140  116590      39790      55012
# 166578    131845   124796      27291   18744      11774      34553
# 167901    959542   914961     268958  133977     183055     342920
# 188302    339142   306523     129272   60161      33887      67719
# 190993    204945   214337      51656   37622      13243      43316
#
#        VPH_SINCINT VPH_SINTIC TAMLOC
# 3           128996       1711      *
# 2061        293529       9582      *
# 7627         77223       2608      *
# 10188       130361      12028      *
# 12988       332298       5754      *
# 17137        82366       2698      *
# 18396       993929     151655      *
# 39883       432032      20158      *
# 52272       561128      10528      *
# 52938       243750      12446      *
# 58944       732192      20559      *
# 67889       599093      70622      *
# 74890       467376      26079      *
# 79806       760439      17553      *
# 90521      1769551      53857      *
# 95657       655580      23842      *
# 104613      227132       7724      *
# 106291      167969       9171      *
# 109204      439479       9797      *
# 114178      736533     106502      *
# 126034      939937      49800      *
# 133093      208004       9228      *
# 135342      221620      12239      *
# 137585      388169      23153      *
# 144314      365642      12648      *
# 149866      302080      11895      *
# 157366      404524      25731      *
# 159883      436801      11760      *
# 166578      183348       5272      *
# 167901     1329356      94369      *
# 188302      283586      16519      *
# 190993      214181       5383      *
#
# [32 rows x 232 columns]

# %% [markdown]
# By using the dictonary that the dataset offers, the selection of columns of interest is done.

# %%
df=df[['ENTIDAD','NOM_ENT','PCON_DISC','PCON_LIMI','PCLIM_PMEN','PSIND_LIM','GRAPROES','PSINDER','PDER_SS','PROM_OCUP',
       'TVIVPARHAB','VPH_SINTIC','POB0_14','POB15_64','POB65_MAS']].copy()

# %% [markdown]
# Based on the dictonary the columns are renamed in a clearer way.

# %%
df.rename(columns = {'ENTIDAD':'cve_ent','NOM_ENT':'states','PCON_DISC': 'population_disability','PCON_LIMI': 'population_limitation',
                     'PCLIM_PMEN': 'population_mental_problem','PSIND_LIM':'population_no_problems','GRAPROES': 'average_years_finish', 'PSINDER': 'no_med_insurance', 
                     'PDER_SS': 'med_insurance', 'PROM_OCUP': 'average_household_size','TVIVPARHAB': 'total_households','VPH_SINTIC': 'household_no_tics',
                    'POB0_14':'population_0_14_years_old','POB15_64':'population_15_64_years_old','POB65_MAS':'population_65_more_years_old'}, inplace=True)

# %% [markdown]
# It is also necessary to change the data types of the columns of interest to int and float data types, since this values will be normalized for further study.

# %%
df['population_disability'] = df['population_disability'].astype(int)
df['population_limitation'] = df['population_limitation'].astype(int)
df['population_mental_problem'] = df['population_mental_problem'].astype(int)
df['population_no_problems'] = df['population_no_problems'].astype(int)
df['average_years_finish'] = df['average_years_finish'].astype(float)
df['no_med_insurance'] = df['no_med_insurance'].astype(int)
df['med_insurance'] = df['med_insurance'].astype(int)
df['average_household_size'] = df['average_household_size'].astype(float)
df['total_households'] = df['total_households'].astype(int)
df['household_no_tics'] = df['household_no_tics'].astype(int)
df['population_0_14_years_old'] = df['population_0_14_years_old'].astype(int)
df['population_15_64_years_old'] = df['population_15_64_years_old'].astype(int)
df['population_65_more_years_old'] = df['population_65_more_years_old'].astype(int)

# %% [markdown]
# To obtain the total household which have TIC's it is necessary to substract from the total household the households that do not have TIC's

# %%
df['household_tics'] = df['total_households']-df['household_no_tics']
df.dtypes
# Out:
# cve_ent                           int64
# states                           object
# population_disability             int32
# population_limitation             int32
# population_mental_problem         int32
# population_no_problems            int32
# average_years_finish            float64
# no_med_insurance                  int32
# med_insurance                     int32
# average_household_size          float64
# total_households                  int32
# household_no_tics                 int32
# population_0_14_years_old         int32
# population_15_64_years_old        int32
# population_65_more_years_old      int32
# household_tics                    int32
# dtype: object

# %% [markdown]
# The week 1 analyzes it is read

# %%
dfWeek1 = pd.read_csv('../data/week1analyzesStates.csv')

# %% [markdown]
# The week 1 analyzes cve_ent is converted to a string value for a good compatibility for future merging

# %%
dfWeek1['cve_ent'] = dfWeek1['cve_ent'].astype('int64')
dfWeek1.head()
# Out:
#    cve_ent                state  population  total_cases    case_rate  \
# 0        1       AGUASCALIENTES     1434635        26694  1860.682334
# 1        2      BAJA CALIFORNIA     3634868        50278  1383.213916
# 2        3  BAJA CALIFORNIA SUR      804708        36223  4501.384353
# 3        4             CAMPECHE     1000617        11081  1107.416724
# 4        7              CHIAPAS     5730367        12050   210.283216
#
#    total_cases_last_60_days  case_rate_last_60_days  total_deaths  death_rate  \
# 0                       793               55.275384          2456  171.193370
# 1                      2349               64.624080          8648  237.917856
# 2                      6266              778.667542          1486  184.663257
# 3                      1628              162.699614          1265  126.421998
# 4                      1095               19.108724          1654   28.863771
#
#    total_deaths_last_60_days  death_rate_last_60_days
# 0                         85                 5.924852
# 1                        174                 4.786969
# 2                        116                14.415167
# 3                         56                 5.596547
# 4                         41                 0.715486

# %% [markdown]
# The week 1 analyzes and the lastest dataframe is merged using the code of the state of origin of the municipality

# %%
dfAll = pd.merge(df,dfWeek1,on=['cve_ent'])
dfAll.head()
# Out:
#    cve_ent                states  population_disability  \
# 0        1        Aguascalientes                  71294
# 1        2       Baja California                 151945
# 2        3   Baja California Sur                  35383
# 3        4              Campeche                  52259
# 4        5  Coahuila de Zaragoza                 134816
#
#    population_limitation  population_mental_problem  population_no_problems  \
# 0                 165482                      20169                 1177938
# 1                 361269                      52519                 3213665
# 2                  90233                      10423                  663217
# 3                 112956                      12314                  753271
# 4                 302543                      35073                 2683785
#
#    average_years_finish  no_med_insurance  med_insurance  \
# 0                 10.35            262088        1161139
# 1                 10.20            836317        2905265
# 2                 10.34            129270         664122
# 3                  9.63            203304         719677
# 4                 10.43            597373        2540708
#
#    average_household_size  ...                state  population  total_cases  \
# 0                    3.68  ...       AGUASCALIENTES     1434635        26694
# 1                    3.26  ...      BAJA CALIFORNIA     3634868        50278
# 2                    3.30  ...  BAJA CALIFORNIA SUR      804708        36223
# 3                    3.55  ...             CAMPECHE     1000617        11081
# 4                    3.48  ...             COAHUILA     3218720        69382
#
#      case_rate  total_cases_last_60_days  case_rate_last_60_days total_deaths  \
# 0  1860.682334                       793               55.275384         2456
# 1  1383.213916                      2349               64.624080         8648
# 2  4501.384353                      6266              778.667542         1486
# 3  1107.416724                      1628              162.699614         1265
# 4  2155.577372                      1344               41.755729         6376
#
#    death_rate  total_deaths_last_60_days  death_rate_last_60_days
# 0  171.193370                         85                 5.924852
# 1  237.917856                        174                 4.786969
# 2  184.663257                        116                14.415167
# 3  126.421998                         56                 5.596547
# 4  198.091167                         67                 2.081573
#
# [5 rows x 26 columns]

# %% [markdown]
# Once merged the dataframes only the data that is possible to normalized is selected. After selecting the data the normalization of it is implemented based on the total population or total households of each municipality by obtain the percentage of people or households with the certain variable of interest.

# %%
dfAll = dfAll[['cve_ent','state','population','population_disability', 'population_limitation',
       'population_mental_problem','population_no_problems', 'average_years_finish', 'no_med_insurance',
       'med_insurance', 'average_household_size', 'case_rate', 
       'case_rate_last_60_days', 'death_rate',
       'death_rate_last_60_days','total_households','household_tics','household_no_tics',
        'population_0_14_years_old','population_15_64_years_old','population_65_more_years_old']].copy()
dfAll['pct_disability']=dfAll['population_disability']/dfAll['population']*100
dfAll['pct_limitation']=dfAll['population_limitation']/dfAll['population']*100
dfAll['pct_mental_problem']=dfAll['population_mental_problem']/dfAll['population']*100
dfAll['pct_no_problems']=dfAll['population_no_problems']/dfAll['population']*100
dfAll['pct_no_med_insurance']=dfAll['no_med_insurance']/dfAll['population']*100
dfAll['pct_med_insurance']=dfAll['med_insurance']/dfAll['population']*100
dfAll['pct_household_tics']=dfAll['household_tics']/dfAll['total_households']*100
dfAll['pct_household_no_tics']=dfAll['household_no_tics']/dfAll['total_households']*100
dfAll['pct_pop_0_14_years_old']=dfAll['population_0_14_years_old']/dfAll['population']*100
dfAll['pct_pop_15_64_years_old']=dfAll['population_15_64_years_old']/dfAll['population']*100
dfAll['pct_pop_65_more_years_old']=dfAll['population_65_more_years_old']/dfAll['population']*100

# %% [markdown]
# Finally the variables and the region codes are selected of the dataframe for future storage

# %%
dfFinal = dfAll[['cve_ent','state','case_rate','case_rate_last_60_days', 'death_rate',
        'death_rate_last_60_days','population','pct_disability',
        'pct_limitation','pct_mental_problem', 'pct_no_problems' ,'average_years_finish',
        'pct_no_med_insurance','pct_med_insurance', 'average_household_size',
        'pct_household_tics','pct_household_no_tics','pct_pop_0_14_years_old',
        'pct_pop_15_64_years_old','pct_pop_65_more_years_old']].copy()
dfFinal
# Out:
#     cve_ent                state    case_rate  case_rate_last_60_days  \
# 0         1       AGUASCALIENTES  1860.682334               55.275384
# 1         2      BAJA CALIFORNIA  1383.213916               64.624080
# 2         3  BAJA CALIFORNIA SUR  4501.384353              778.667542
# 3         4             CAMPECHE  1107.416724              162.699614
# 4         5             COAHUILA  2155.577372               41.755729
# 5         6               COLIMA  1554.219369              130.547804
# 6         7              CHIAPAS   210.283216               19.108724
# 7         8            CHIHUAHUA  1512.118810              119.505867
# 8         9     DISTRITO FEDERAL  7466.121574              360.187146
# 9        10              DURANGO  1850.619263               63.403025
# 10       11           GUANAJUATO  2129.837392               36.639947
# 11       12             GUERRERO  1137.748260               60.595322
# 12       13              HIDALGO  1275.752378               39.236473
# 13       14              JALISCO  1047.957399               34.424562
# 14       15               MEXICO  1472.682423               48.881700
# 15       16            MICHOACAN  1016.640897               32.349643
# 16       17              MORELOS  1673.778337               96.425835
# 17       18              NAYARIT   972.550213               64.102017
# 18       19           NUEVO LEON  2247.140140               84.061879
# 19       20               OAXACA  1157.618521               46.071127
# 20       21               PUEBLA  1301.319368               43.576673
# 21       22            QUERETARO  3051.406869               96.155660
# 22       23         QUINTANA ROO  1780.057438              459.942469
# 23       24      SAN LUIS POTOSI  2269.252535               80.700817
# 24       25              SINALOA  1299.437319              101.689310
# 25       26               SONORA  2531.071682              154.289217
# 26       27              TABASCO  2855.941036              390.547400
# 27       28           TAMAULIPAS  1729.084682              189.913883
# 28       29             TLAXCALA  1457.307224               42.390966
# 29       30             VERACRUZ   745.316493               45.691605
# 30       31              YUCATAN  1962.243338              329.467779
# 31       32            ZACATECAS  1858.108311               70.870234
#
#     death_rate  death_rate_last_60_days  population  pct_disability  \
# 0   171.193370                 5.924852     1434635        4.969487
# 1   237.917856                 4.786969     3634868        4.180207
# 2   184.663257                14.415167      804708        4.396999
# 3   126.421998                 5.596547     1000617        5.222678
# 4   198.091167                 2.081573     3218720        4.188497
# 5   154.110091                 4.330366      785153        5.079265
# 6    28.863771                 0.715486     5730367        3.976674
# 7   197.107079                10.758948     3801487        4.413747
# 8   382.075134                 7.096410     9018645        5.472984
# 9   133.494133                 3.691822     1868996        5.454961
# 10  177.885175                 1.878560     6228175        4.585854
# 11  124.335256                 4.757936     3657048        5.841187
# 12  203.083579                 4.730409     3086414        5.409676
# 13  149.874674                 3.139235     8409693        4.596803
# 14  213.492359                 4.171499    17427790        4.340946
# 15  123.057130                 5.222364     4825401        5.348923
# 16  172.989220                 8.218945     2044058        5.345005
# 17  144.966789                 5.277164     1288571        5.293926
# 18  172.758212                 3.671914     5610153        3.925134
# 19   94.024679                 2.847770     4143593        6.609626
# 20  184.284810                 8.040032     6604451        4.544662
# 21  195.294251                 6.272929     2279637        4.218215
# 22  170.606972                19.439910     1723259        3.888272
# 23  189.383499                 3.523901     2866142        5.019326
# 24  201.541242                 6.240746     3156674        4.687149
# 25  219.172647                 4.683315     3074745        4.731222
# 26  164.600606                 6.764408     2572287        5.623517
# 27  141.538300                 7.231684     3650602        4.647151
# 28  182.969556                 2.898528     1380011        3.936418
# 29  117.835628                 2.974287     8539862        5.491775
# 30  181.399833                14.784662     2259098        5.753889
# 31  169.944540                 4.140598     1666426        5.756871
#
#     pct_limitation  pct_mental_problem  pct_no_problems  average_years_finish  \
# 0        11.534781            1.405863        82.107156                 10.35
# 1         9.938985            1.444867        88.412151                 10.20
# 2        11.213136            1.295252        82.417100                 10.34
# 3        11.288635            1.230641        75.280652                  9.63
# 4         9.399482            1.089657        83.380505                 10.43
# 5        11.122036            1.277713        76.114337                 10.05
# 6         7.333928            0.929417        84.528565                  7.78
# 7        10.381148            1.296835        82.710476                 10.00
# 8        12.653985            1.612526        83.044837                 11.48
# 9        11.655991            1.202624        80.213173                  9.75
# 10        9.854396            1.196081        83.743745                  9.04
# 11       11.951415            1.278162        78.070263                  8.37
# 12       13.388936            1.249055        80.425018                  9.37
# 13        9.822142            1.303139        83.546997                  9.90
# 14       11.067668            1.178044        81.400585                 10.08
# 15       11.275830            1.183135        81.105695                  8.60
# 16       12.563342            1.197716        77.931937                  9.84
# 17       12.163940            1.292517        77.750702                  9.73
# 18        9.828146            1.233817        88.236203                 10.74
# 19       13.332559            1.185276        79.127366                  8.12
# 20       10.391325            1.065933        84.163014                  9.16
# 21       10.738245            1.274633        87.949967                 10.48
# 22        9.523641            1.181018        92.423716                 10.24
# 23       11.713970            1.358760        81.004047                  9.61
# 24       10.244834            1.300324        80.201155                 10.22
# 25       10.342191            1.309767        79.945687                 10.40
# 26        9.949317            1.178873        77.287177                  9.69
# 27       10.579789            1.272639        80.609363                 10.09
# 28       10.370280            0.948543        81.003340                  9.83
# 29       12.066179            1.233416        76.281642                  8.75
# 30       12.040602            1.501661        84.132030                  9.59
# 31       12.016735            1.148866        78.941459                  9.25
#
#     pct_no_med_insurance  pct_med_insurance  average_household_size  \
# 0              18.268619          80.936196                    3.68
# 1              23.008181          79.927662                    3.26
# 2              16.064212          82.529564                    3.30
# 3              20.317864          71.923323                    3.55
# 4              18.559334          78.935353                    3.48
# 5              15.675161          77.175659                    3.21
# 6              31.669560          64.544958                    4.09
# 7              15.102196          83.027878                    3.25
# 8              27.751275          74.168703                    3.32
# 9              24.686730          73.122949                    3.69
# 10             20.474537          78.267887                    3.87
# 11             24.390191          71.970726                    3.74
# 12             30.085076          69.639815                    3.59
# 13             29.163003          69.392664                    3.56
# 14             32.549015          64.653505                    3.71
# 15             36.984056          61.229233                    3.68
# 16             27.013421          69.317211                    3.50
# 17             21.189286          74.544825                    3.39
# 18             19.120049          83.446298                    3.49
# 19             29.346270          70.101069                    3.65
# 20             29.100753          70.421932                    3.83
# 21             21.339669          82.169223                    3.53
# 22             27.191502          79.229414                    3.22
# 23             17.106061          81.205048                    3.63
# 24             18.219018          77.534614                    3.49
# 25             17.813737          77.778125                    3.34
# 26             29.370129          63.954333                    3.58
# 27             19.554556          76.793006                    3.29
# 28             25.843345          69.897921                    3.93
# 29             26.095035          68.215774                    3.37
# 30             22.358835          80.125829                    3.52
# 31             19.577107          77.594745                    3.65
#
#     pct_household_tics  pct_household_no_tics  pct_pop_0_14_years_old  \
# 0            99.557246               0.442754               26.849687
# 1            99.165994               0.834006               24.163271
# 2            98.915448               1.084552               24.487516
# 3            95.386710               4.613290               24.096932
# 4            99.361293               0.638707               25.608938
# 5            98.810684               1.189316               22.054682
# 6            88.774803              11.225197               30.889400
# 7            98.241618               1.758382               24.788274
# 8            99.618041               0.381959               18.326179
# 9            97.479026               2.520974               27.496260
# 10           98.704154               1.295846               26.262782
# 11           92.503315               7.496685               28.300449
# 12           96.957561               3.042439               25.641991
# 13           99.246881               0.753119               25.018618
# 14           98.821158               1.178842               23.652265
# 15           98.144077               1.855923               26.906033
# 16           98.622360               1.377640               22.922588
# 17           97.461455               2.538545               25.677902
# 18           99.408128               0.591872               24.624070
# 19           90.540656               9.459344               27.680663
# 20           97.093466               2.906534               26.962181
# 21           98.619569               1.380431               25.594557
# 22           97.873287               2.126713               26.542731
# 23           97.011197               2.988803               25.345499
# 24           98.520383               1.479617               23.661107
# 25           98.642639               1.357361               23.541692
# 26           96.155553               3.844447               25.410578
# 27           98.900031               1.099969               23.873788
# 28           98.456571               1.543429               25.211103
# 29           96.052705               3.947295               22.961764
# 30           97.489838               2.510162               24.401111
# 31           98.783841               1.216159               27.532216
#
#     pct_pop_15_64_years_old  pct_pop_65_more_years_old
# 0                 65.649730                   6.766181
# 1                 72.553336                   6.747975
# 2                 68.228351                   6.028646
# 3                 61.273494                   6.979494
# 4                 64.831517                   7.132866
# 5                 62.982629                   7.866238
# 6                 59.278524                   6.090901
# 7                 66.104317                   7.338181
# 8                 72.354993                  11.333244
# 9                 62.741119                   7.648063
# 10                65.062799                   7.497670
# 11                59.461566                   8.661877
# 12                65.560583                   8.577786
# 13                65.484400                   8.158134
# 14                66.581993                   7.220388
# 15                62.671206                   8.763106
# 16                64.215057                   9.267252
# 17                61.596373                   8.513074
# 18                70.373304                   7.786098
# 19                62.288671                   9.527890
# 20                64.817621                   7.813746
# 21                71.006349                   6.996421
# 22                75.312649                   4.742816
# 23                64.194691                   8.860831
# 24                63.608817                   8.549853
# 25                64.443295                   7.701484
# 26                61.247054                   6.711498
# 27                64.762387                   7.843282
# 28                63.387538                   7.201464
# 29                61.923296                   9.485423
# 30                69.212358                   8.953219
# 31                61.192996                   8.505628

# %% [markdown]
# The dataframe is stored

# %%
dfFinal.to_csv('../data/week3_variables_states.csv',index=False)
