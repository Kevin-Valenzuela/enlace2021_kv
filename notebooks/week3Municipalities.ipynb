# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from string import ascii_letters
import numpy as np

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# The dataset "conjunto_de_datos_iter_00CSV20.csv" must be downloaded from: https://inegi.org.mx/programas/ccpv/2020/#Datos_abiertos, in the section 'Principales resultados por localidad (ITER)' and subsection 'Estados Unidos Mexicanos' it will be accessible. After downloading the dataset it must be relocated to the data folder.

# %%
df = pd.read_csv('../data/conjunto_de_datos_iter_00CSV20.csv')
# Out:
# C:\Users\TheAl\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# By using this query only the totals of each variable for each municipality is used well the rest of the dataframe is ignored.

# %%
df.query("NOM_LOC == 'Total del Municipio'", inplace = True)
df
# Out:
#         ENTIDAD         NOM_ENT  MUN                NOM_MUN  LOC  \
# 6             1  Aguascalientes    1         Aguascalientes    0
# 574           1  Aguascalientes    2               Asientos    0
# 749           1  Aguascalientes    3               Calvillo    0
# 918           1  Aguascalientes    4                  Cosío    0
# 985           1  Aguascalientes    5            Jesús María    0
# ...         ...             ...  ...                    ...  ...
# 195372       32       Zacatecas   54          Villa Hidalgo    0
# 195422       32       Zacatecas   55             Villanueva    0
# 195542       32       Zacatecas   56              Zacatecas    0
# 195616       32       Zacatecas   57               Trancoso    0
# 195641       32       Zacatecas   58  Santa María de la Paz    0
#
#                     NOM_LOC LONGITUD LATITUD ALTITUD  POBTOT  ... VPH_CEL  \
# 6       Total del Municipio      NaN     NaN     NaN  948990  ...  251719
# 574     Total del Municipio      NaN     NaN     NaN   51536  ...   10682
# 749     Total del Municipio      NaN     NaN     NaN   58250  ...   13666
# 918     Total del Municipio      NaN     NaN     NaN   17000  ...    3424
# 985     Total del Municipio      NaN     NaN     NaN  129929  ...   31408
# ...                     ...      ...     ...     ...     ...  ...     ...
# 195372  Total del Municipio      NaN     NaN     NaN   19446  ...    3929
# 195422  Total del Municipio      NaN     NaN     NaN   31558  ...    7418
# 195542  Total del Municipio      NaN     NaN     NaN  149607  ...   39755
# 195616  Total del Municipio      NaN     NaN     NaN   20455  ...    3834
# 195641  Total del Municipio      NaN     NaN     NaN    2767  ...     666
#
#        VPH_INTER VPH_STVP VPH_SPMVPI VPH_CVJ VPH_SINRTV VPH_SINLTC  \
# 6         178619   130290      80951   56131       3299       7293
# 574         4526     3882        596     556        377       1447
# 749         6553     4749       1382    1352        443        904
# 918         1741     1664        223     191        139        414
# 985        19920    13483       9296    6582        480       1150
# ...          ...      ...        ...     ...        ...        ...
# 195372      1150     1090        109     106        160        744
# 195422      4411     5181        643     569        306        746
# 195542     31989    28630      11944    7639        681       1185
# 195616      1092     1854        204     185        130        677
# 195641       264      427         37      23         59        114
#
#        VPH_SINCINT VPH_SINTIC TAMLOC
# 6            74227        731      *
# 574           7206        177      *
# 749           8061        138      *
# 918           1912         50      *
# 985          11447        148      *
# ...            ...        ...    ...
# 195372        3569         80      *
# 195422        4252        101      *
# 195542        8783        129      *
# 195616        3274         59      *
# 195641         542         32      *
#
# [2469 rows x 232 columns]

# %% [markdown]
# By using the dictonary that the dataset offers, the selection of columns of interest is done.

# %%
df=df[['ENTIDAD','NOM_ENT','MUN','NOM_MUN','PCON_DISC','PCON_LIMI','PCLIM_PMEN','PSIND_LIM','GRAPROES','PSINDER','PDER_SS','PROM_OCUP',
       'TVIVPARHAB','VPH_SINTIC','POB0_14','POB15_64','POB65_MAS']].copy()

# %% [markdown]
# Based on the dictonary the columns are renamed in a clearer way.

# %%
df.rename(columns = {'MUN':'municipalitie_number', 'NOM_MUN': 'municipalities','PCON_DISC': 'population_disability','PCON_LIMI': 'population_limitation',
                     'PCLIM_PMEN': 'population_mental_problem','PSIND_LIM':'population_no_problems','GRAPROES': 'average_years_finish', 'PSINDER': 'no_med_afilation', 
                     'PDER_SS': 'med_afilation', 'PROM_OCUP': 'average_household_size','TVIVPARHAB': 'total_households','VPH_SINTIC': 'household_no_tics',
                    'POB0_14':'population_0_14_years_old','POB15_64':'population_15_64_years_old','POB65_MAS':'population_65_more_years_old'}, inplace=True)

# %% [markdown]
# To properly merge the dataframe from the week 1 analyzes with the dataframe that is currently being analyze it is necessary to obtain the code that describes the state of origin of the municipality.

# %%
df['mun_num'] = df['municipalitie_number'].apply(lambda i: f'{i:03d}')
df['ENTIDAD'] = df['ENTIDAD'].astype(str)
df['cve_ent'] = df['ENTIDAD'] + df['mun_num']

# %% [markdown]
# It is also necessary to change the data types of the columns of interest to int and float data types, since this values will be normalized for further study.

# %%
df['population_disability'] = df['population_disability'].astype(int)
df['population_limitation'] = df['population_limitation'].astype(int)
df['population_mental_problem'] = df['population_mental_problem'].astype(int)
df['population_no_problems'] = df['population_no_problems'].astype(int)
df['average_years_finish'] = df['average_years_finish'].astype(float)
df['no_med_afilation'] = df['no_med_afilation'].astype(int)
df['med_afilation'] = df['med_afilation'].astype(int)
df['average_household_size'] = df['average_household_size'].astype(float)
df['total_households'] = df['total_households'].astype(int)
df['household_no_tics'] = df['household_no_tics'].astype(int)
df['population_0_14_years_old'] = df['population_0_14_years_old'].astype(int)
df['population_15_64_years_old'] = df['population_15_64_years_old'].astype(int)
df['population_65_more_years_old'] = df['population_65_more_years_old'].astype(int)

# %% [markdown]
# To obtain the total household which have TIC's it is necessary to substract from the total household the households that do not have TIC's

# %%
df['household_tics'] = df['total_households']-df['household_no_tics']

# %% [markdown]
# The week 1 analyzes it is read, so that future correlation between the previous dataframe and it can be observed.

# %%
dfWeek1 = pd.read_csv('../data/week1analyzesMunicipalities.csv')
dfWeek1['cve_ent'] = dfWeek1['cve_ent'].astype('str')
dfWeek1
# Out:
#      cve_ent         municipalitie  population  total_cases   cases_rate  \
# 0      31001                 Abala        7035           57   810.234542
# 1      11001               Abasolo       95581          693   725.039495
# 2      19001               Abasolo        2918           28   959.561343
# 3      28001               Abasolo       12768           46   360.275689
# 4       5001               Abasolo        1130            7   619.469027
# ...      ...                   ...         ...          ...          ...
# 2452   21216             Zoquiapan        2583            2    77.429346
# 2453   21217             Zoquitlan       19699            6    30.458399
# 2454   30203  Zozocolco de Hidalgo       15708           10    63.661828
# 2455   15119           Zumpahuacan       17962           88   489.923171
# 2456   15120              Zumpango      217166         2607  1200.464161
#
#       cases_rate_last_60_days  total_deaths  deaths_rate  \
# 0                   28.429282            10   142.146411
# 1                    4.184932            92    96.253439
# 2                    0.000000             3   102.810144
# 3                   62.656642             4    31.328321
# 4                    0.000000             1    88.495575
# ...                       ...           ...          ...
# 2452                38.714673             0     0.000000
# 2453                 5.076400             3    15.229199
# 2454                 6.366183             2    12.732366
# 2455                 5.567309            16    89.076940
# 2456                34.075316           432   198.926167
#
#       deaths_rate_last_60_days
# 0                     0.000000
# 1                     1.046233
# 2                     0.000000
# 3                     0.000000
# 4                     0.000000
# ...                        ...
# 2452                  0.000000
# 2453                  0.000000
# 2454                  0.000000
# 2455                  5.567309
# 2456                  0.920954
#
# [2457 rows x 9 columns]

# %% [markdown]
# The week 1 analyzes and the lastest dataframe is merged using the code of the state of origin of the municipality.

# %%
dfAll = pd.merge(df,dfWeek1,on=['cve_ent'])
dfAll
# Out:
#      ENTIDAD         NOM_ENT  municipalitie_number         municipalities  \
# 0          1  Aguascalientes                     1         Aguascalientes
# 1          1  Aguascalientes                     2               Asientos
# 2          1  Aguascalientes                     3               Calvillo
# 3          1  Aguascalientes                     4                  Cosío
# 4          1  Aguascalientes                     5            Jesús María
# ...      ...             ...                   ...                    ...
# 2452      32       Zacatecas                    54          Villa Hidalgo
# 2453      32       Zacatecas                    55             Villanueva
# 2454      32       Zacatecas                    56              Zacatecas
# 2455      32       Zacatecas                    57               Trancoso
# 2456      32       Zacatecas                    58  Santa María de la Paz
#
#       population_disability  population_limitation  population_mental_problem  \
# 0                     47525                 116705                      13945
# 1                      2886                   4551                        692
# 2                      4088                   6760                       1191
# 3                       805                   1933                        206
# 4                      5036                  11904                       1642
# ...                     ...                    ...                        ...
# 2452                   1404                   2233                        201
# 2453                   2129                   3954                        420
# 2454                   8455                  20144                       1830
# 2455                   1020                   1958                        268
# 2456                    174                    320                         38
#
#       population_no_problems  average_years_finish  no_med_afilation  ...  \
# 0                     777394                 10.84            173199  ...
# 1                      43707                  8.54              7590  ...
# 2                      46834                  8.05             11832  ...
# 3                      14166                  9.08              2347  ...
# 4                     112021                 10.22             27299  ...
# ...                      ...                   ...               ...  ...
# 2452                   15733                  8.02              3009  ...
# 2453                   25279                  8.08              7941  ...
# 2454                  119968                 11.57             25350  ...
# 2455                   17295                  8.61              2831  ...
# 2456                    2257                  8.00               411  ...
#
#       cve_ent  household_tics          municipalitie  population  total_cases  \
# 0        1001          266047         Aguascalientes      961977        22076
# 1        1002           12365               Asientos       50864          464
# 2        1003           15408               Calvillo       60760          982
# 3        1004            3887                  Cosio       16918          130
# 4        1005           33066            Jesus Maria      130184          779
# ...       ...             ...                    ...         ...          ...
# 2452    32054            4871          Villa Hidalgo       20177           97
# 2453    32055            8944             Villanueva       31804          425
# 2454    32056           42265              Zacatecas      155533         7623
# 2455    32057            4610               Trancoso       20285          241
# 2456    32058             828  Santa Maria de la Paz        2855           29
#
#        cases_rate  cases_rate_last_60_days total_deaths deaths_rate  \
# 0     2294.857361                70.687761         2143  222.770399
# 1      912.236552                29.490406           36   70.776974
# 2     1616.194865                 8.229098           26   42.791310
# 3      768.412342                29.554321           12   70.930370
# 4      598.383826                16.131015           62   47.624900
# ...           ...                      ...          ...         ...
# 2452   480.745403                 9.912276           21  104.078902
# 2453  1336.309898                37.731103           52  163.501446
# 2454  4901.210676               214.745424          557  358.123356
# 2455  1188.070002                59.157013           34  167.611536
# 2456  1015.761821                 0.000000            3  105.078809
#
#       deaths_rate_last_60_days
# 0                     7.484586
# 1                     1.966027
# 2                     0.000000
# 3                     0.000000
# 4                     0.768144
# ...                        ...
# 2452                  4.956138
# 2453                  3.144259
# 2454                  7.072454
# 2455                  4.929751
# 2456                  0.000000
#
# [2457 rows x 28 columns]

# %% [markdown]
# Once merged the dataframes only the data that is possible to normalized is selected. After selecting the data the normalization of it is implemented based on the total population or total households of each municipality by obtain the percentage of people or households with the certain variable of interest.

# %%
dfAll = dfAll[['cve_ent','municipalitie','population','population_disability', 'population_limitation',
       'population_mental_problem','population_no_problems', 'average_years_finish', 'no_med_afilation',
       'med_afilation', 'average_household_size', 'cases_rate', 
       'cases_rate_last_60_days', 'deaths_rate',
       'deaths_rate_last_60_days','total_households','household_tics','household_no_tics',
        'population_0_14_years_old','population_15_64_years_old','population_65_more_years_old']].copy()
dfAll['pct_disability']=dfAll['population_disability']/dfAll['population']*100
dfAll['pct_limitation']=dfAll['population_limitation']/dfAll['population']*100
dfAll['pct_mental_problem']=dfAll['population_mental_problem']/dfAll['population']*100
dfAll['pct_no_problems']=dfAll['population_no_problems']/dfAll['population']*100
dfAll['pct_no_med_afilation']=dfAll['no_med_afilation']/dfAll['population']*100
dfAll['pct_med_afilation']=dfAll['med_afilation']/dfAll['population']*100
dfAll['pct_household_tics']=dfAll['household_tics']/dfAll['total_households']*100
dfAll['pct_household_no_tics']=dfAll['household_no_tics']/dfAll['total_households']*100
dfAll['pct_pop_0_14_years_old']=dfAll['population_0_14_years_old']/dfAll['population']*100
dfAll['pct_pop_15_64_years_old']=dfAll['population_15_64_years_old']/dfAll['population']*100
dfAll['pct_pop_65_more_years_old']=dfAll['population_65_more_years_old']/dfAll['population']*100

# %% [markdown]
# The data normalized is only selected to create a much simplier interpretation of the correlation.

# %%
dfFinal = dfAll[['cases_rate','cases_rate_last_60_days', 'deaths_rate',
        'deaths_rate_last_60_days','population','pct_disability',
        'pct_limitation','pct_mental_problem', 'pct_no_problems' ,'average_years_finish',
        'pct_no_med_afilation','pct_med_afilation', 'average_household_size',
        'pct_household_tics','pct_household_no_tics','pct_pop_0_14_years_old',
        'pct_pop_15_64_years_old','pct_pop_65_more_years_old']].copy()

# %% [markdown]
# The correlation of the data can be observed graphically using a pairplot as following

# %%
sns.pairplot(dfFinal)

# %% [markdown]
# Also the correlation is ilustrated using a diagonal correlation matrix map to simplify it as following

# %%
corr = dfFinal.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
heatmap=sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
sns.set_context('paper', font_scale=0.5)
heatmap = heatmap.get_figure()
#heatmap.savefig("../heatmap.png", bbox_inches="tight")

# %%
dfFinal = dfAll[['cve_ent','municipalitie','cases_rate','cases_rate_last_60_days', 'deaths_rate',
        'deaths_rate_last_60_days','population','pct_disability',
        'pct_limitation','pct_mental_problem', 'pct_no_problems' ,'average_years_finish',
        'pct_no_med_afilation','pct_med_afilation', 'average_household_size',
        'pct_household_tics','pct_household_no_tics','pct_pop_0_14_years_old',
        'pct_pop_15_64_years_old','pct_pop_65_more_years_old']].copy()

# %%
#dfFinal.to_csv('../data/week3analyzesMunicipalities.csv',index=False)
